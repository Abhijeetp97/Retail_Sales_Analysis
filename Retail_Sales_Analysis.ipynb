# %% [markdown]
# Retail sales

# %%
import pandas as pd
df_retail = pd.read_csv('/content/retail_sales_dataset.csv')

df_retail
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  2023-11-24     CUST001    Male   34           Beauty
# 1                 2  2023-02-27     CUST002  Female   26         Clothing
# 2                 3  2023-01-13     CUST003    Male   50      Electronics
# 3                 4  2023-05-21     CUST004    Male   37         Clothing
# 4                 5  2023-05-06     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# ...

# %%
print(df_retail.info())
print(df_retail.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB
# None
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# ...

# %%
print(df_retail.isnull().sum())
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
# Sales by product category
sales_by_category = df_retail.groupby('Product Category')['Total Amount'].sum()

print(sales_by_category)
# Out:
# Product Category
# Beauty         143515
# Clothing       155580
# Electronics    156905
# Name: Total Amount, dtype: int64

# %%
# Customer demographics
gender_distribution = df_retail['Gender'].value_counts()

print(gender_distribution)
# Out:
# Gender
# Female    510
# Male      490
# Name: count, dtype: int64

# %%
age_distribution = df_retail['Age'].describe()

print(age_distribution)
# Out:
# count    1000.00000
# mean       41.39200
# std        13.68143
# min        18.00000
# 25%        29.00000
# 50%        42.00000
# 75%        53.00000
# max        64.00000
# Name: Age, dtype: float64

# %%
# Top customers
top_customers = df_retail.groupby('Customer ID')['Total Amount'].sum().sort_values(ascending=False).head(10)

print(top_customers)
# Out:
# Customer ID
# CUST487    2000
# CUST476    2000
# CUST773    2000
# CUST503    2000
# CUST093    2000
# CUST089    2000
# CUST946    2000
# CUST157    2000
# CUST155    2000
# CUST420    2000
# Name: Total Amount, dtype: int64

# %%
# Sales trends over time
df_retail['Date'] = pd.to_datetime(df_retail['Date'])

sales_trend = df_retail.groupby(df_retail['Date'].dt.to_period('M'))['Total Amount'].sum()

print(sales_trend)
# Out:
# Date
# 2023-01    35450
# 2023-02    44060
# 2023-03    28990
# 2023-04    33870
# 2023-05    53150
# 2023-06    36715
# 2023-07    35465
# 2023-08    36960
# 2023-09    23620
# 2023-10    46580
# 2023-11    34920
# 2023-12    44690
# 2024-01     1530
# Freq: M, Name: Total Amount, dtype: int64

# %%
# Average order value
average_order_value = df_retail['Total Amount'].mean()

print(f"The average order value is: {average_order_value}")
# Out:
# The average order value is: 456.0
